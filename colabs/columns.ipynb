# %%
import pandas as pd

# %%
ds = pd.read_csv("C:/Users/Usuario/Documents/Excelsius/word_count/out/last_target.csv")

# %%
ds
# Out:
#                                              content_join  score appVersion  \
# 0                                                   buena      5     3.31.2
# 1                                           buen servicio      5     3.30.0
# 2                                               excelente      5     3.27.0
# 3                                rapido efectivo aspectos      5     3.31.2
# 4       app buena solo malo mas actualizaciones consta...      5        NaN
# ...                                                   ...    ...        ...
# 120783  mala app registrarme aparece ups inconveniente...      1    1.87.81
# 120784                                            fea app      1    1.87.81
# 120785  hola dia hoy descarga aplicacion registre fina...      1    1.87.81
# 120786  pesima hoy  no 2020 no da pide confirmar ident...      1    1.87.81
# 120787                                           no sirve      1        NaN
#
#                          at    label    target last_target
# 0       2024-11-06 21:59:58  4 stars  Positivo    Positivo
# 1       2024-11-06 21:46:29  5 stars  Positivo    Positivo
# 2       2024-11-06 21:40:41  5 stars  Positivo    Positivo
# 3       2024-11-06 21:39:22  5 stars  Positivo    Positivo
# 4       2024-11-06 21:34:35  3 stars   Neutral    Negativo
# ...                     ...      ...       ...         ...
# 120783  2020-11-09 02:01:18   1 star  Negativo    Negativo
# 120784  2020-11-09 01:56:06   1 star  Negativo    Negativo
# 120785  2020-11-09 01:46:15   1 star  Negativo    Negativo
# 120786  2020-11-09 00:13:25   1 star  Negativo    Negativo
# 120787  2020-11-08 23:39:14   1 star  Negativo    Negativo
#
# [120788 rows x 7 columns]

# %%
ds2 = ds[['content_join', 'appVersion', 'at', 'last_target']]

# %%
ds2.rename(columns={'content_join': 'reviews', 'last_target':'label'}, inplace= True)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9368\970525388.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ds2.rename(columns={'content_join': 'reviews', 'last_target':'label'}, inplace= True)

# %%
ds2
# Out:
#                                                   reviews appVersion  \
# 0                                                   buena     3.31.2
# 1                                           buen servicio     3.30.0
# 2                                               excelente     3.27.0
# 3                                rapido efectivo aspectos     3.31.2
# 4       app buena solo malo mas actualizaciones consta...        NaN
# ...                                                   ...        ...
# 120783  mala app registrarme aparece ups inconveniente...    1.87.81
# 120784                                            fea app    1.87.81
# 120785  hola dia hoy descarga aplicacion registre fina...    1.87.81
# 120786  pesima hoy  no 2020 no da pide confirmar ident...    1.87.81
# 120787                                           no sirve        NaN
#
#                          at     label
# 0       2024-11-06 21:59:58  Positivo
# 1       2024-11-06 21:46:29  Positivo
# 2       2024-11-06 21:40:41  Positivo
# 3       2024-11-06 21:39:22  Positivo
# 4       2024-11-06 21:34:35  Negativo
# ...                     ...       ...
# 120783  2020-11-09 02:01:18  Negativo
# 120784  2020-11-09 01:56:06  Negativo
# 120785  2020-11-09 01:46:15  Negativo
# 120786  2020-11-09 00:13:25  Negativo
# 120787  2020-11-08 23:39:14  Negativo
#
# [120788 rows x 4 columns]

# %%
ds2.to_csv('../out/model_yape_target.csv', index=False)
