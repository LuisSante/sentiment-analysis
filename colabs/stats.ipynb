# %%
import pandas as pd ## pip install pandas

# %%
with open('../word_count/reduce.txt', 'r', encoding='utf-8') as file:
    key = []
    value = []
    for line in file:
        parts = line.split()
        if len(parts) == 2:
            word, count = parts[0], int(parts[1])
            # dict_words[word] = count
            key.append(word)
            value.append(count)

# %%
dict_words = {
    "key": key,
    "value": value
}

# %%
df = pd.DataFrame(dict_words)
df
# Out:
#                 key  value
# 0                no  50928
# 1             buena  19837
# 2             llave  18421
# 3        aplicacion  17377
# 4             puedo  13852
# ...             ...    ...
# 27461      editarlo      1
# 27462       basaran      1
# 27463  sorprendidas      1
# 27464  preguntasdoy      1
# 27465   contestadas      1
#
# [27466 rows x 2 columns]

# %%
# %pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Error parsing requirements for sqlparse: [Errno 2] No such file or directory: 'c:\\users\\usuario\\appdata\\local\\programs\\python\\python310\\lib\\site-packages\\sqlparse-0.2.4.dist-info\\METADATA'
#
# [notice] A new release of pip is available: 23.3.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df2 = df.head(50)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(30, 20))
ax.bar(df2['key'], df2['value'], width=1, edgecolor="white", linewidth=0.8)

ax.set()

plt.show()
